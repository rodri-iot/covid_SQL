# %%
# pip install beautifulsoup4
# pip install requests
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Extraer datos de un sitio web
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
response = requests.get(url)
response

# Debe dar como respuesta '200' para confirmar la conexión
# Out:
# <Response [200]>

# %%
if response:
    # wb write binary para escribir
    with open('data.csv', 'wb') as dataset:
        dataset.write(response.content)

# %%
url_1 = "https://en.wikipedia.org/wiki/Gun_death_and_violence_in_the_United_States_by_state#Gun_death_rates"
response_1 = requests.get(url_1)
response_1
# Out:
# <Response [200]>

# %%
# Se obtiene el código de todo el sitio web en una linea de texto
# b' = es un contenido binary ASCI
response_1.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Gun death and violence in the United States by state - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vect
# ...

# %%
if response_1:
    soup = BeautifulSoup(response_1.text, 'html')
    soup

# %%
table = soup.find('table', {'class': 'wikitable'})
table
# Out:
# <table class="wikitable sortable sticky-header static-row-numbers sort-under col1left" style="text-align:right">
# <caption>Gun death rates per 100,000 people
# </caption>
# <tbody><tr>
# <th>Location</th>
# <th>Gun <br/> suicide <br/> rate</th>
# <th>Suicide <br/> rate</th>
# <th>Gun <br/> homicide <br/> rate</th>
# <th>Homicide <br/> rate</th>
# <th>% <br/> gun at <br/> home
# </th></tr>
# <tr class="static-row-numbers-norank">
# <td><span class="flagicon" style="padding-left:25px;"> </span><b>United States</b></td>
# <td>7.9</td>
# <td>14.5</td>
# <td>6.3</td>
# <td>7.8</td>
# <td><sup class="reference" id="cite_ref-11"><a href="#cite_note-11"><span class="cite-bracket">[</span>a<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# ...

# %%
rows = table.find_all('tr')
data = []
for row in rows:
    cells = row.find_all(['td', 'th'])
    cells = [cell.get_text(strip = True) for cell in cells]
    data.append(cells)

# %%
data
# Out:
# [['Location',
#   'Gunsuiciderate',
#   'Suiciderate',
#   'Gunhomiciderate',
#   'Homiciderate',
#   '%gun athome'],
#  ['United States', '7.9', '14.5', '6.3', '7.8', '[a]'],
#  ['Wyoming', '23.7', '32.8', '1.7', '2.8', '61%'],
#  ['Montana', '21.6', '31.7', '2.7', '4.2', '65%'],
#  ['Alaska', '19.4', '30.0', '4.2', '6.7', '57%'],
#  ['New Mexico', '14.4', '25.2', '10.9', '14.5', '36%'],
#  ['Oklahoma', '13.8', '22.0', '6.4', '8.6', '55%'],
#  ['Idaho', '13.8', '20.4', '1.5', '2.2', '58%'],
#  ['North Dakota', '13.2', '20.1', '2.6', '3.1', '53%'],
#  ['Nevada', '13.1', '22.0', '6.3', '8.4', '33%'],
#  ['Arkansas', '12.9', '20.4', '9.3', '11.1', '52%'],
#  ['Colorado', '12.8', '23.8', '4.7', '6.3', '38%'],
#  ['West Virginia', '12.7', '21.0', '4.8', '6.4', '60%'],
#  ['Alabama', '12.4', '16.4', '12.9', '14.8', '53%'],
#  ['Missouri', '12.1', '19.1', '9.9', '11.6', '53%'],
#  ['Arizona', '12.1', '20.3', '5.9', '7.7', '36%'],
#  ['Oregon', '11.9', '20.9', '3.4', '4.8', '41%'],
# ...

# %%
df = pd.DataFrame(data)
df

# Casi listo, se debe convertir la primera fila en columnas y despues eliminarla
# Out:
#                        0               1            2                3  \
# 0               Location  Gunsuiciderate  Suiciderate  Gunhomiciderate
# 1          United States             7.9         14.5              6.3
# 2                Wyoming            23.7         32.8              1.7
# 3                Montana            21.6         31.7              2.7
# 4                 Alaska            19.4         30.0              4.2
# 5             New Mexico            14.4         25.2             10.9
# 6               Oklahoma            13.8         22.0              6.4
# 7                  Idaho            13.8         20.4              1.5
# 8           North Dakota            13.2         20.1              2.6
# 9                 Nevada            13.1         22.0              6.3
# 10              Arkansas            12.9         20.4              9.3
# 11              Colorado            12.8         23.8              4.7
# ...

# %%
# Extraer toda la fila, las columnas
my_colums = df.loc[0, :].to_list()
my_colums
# Out:
# ['Location',
#  'Gunsuiciderate',
#  'Suiciderate',
#  'Gunhomiciderate',
#  'Homiciderate',
#  '%gun athome']

# %%
# Renonbrar las columnas
df.columns = my_colums
df
# Out:
#                 Location  Gunsuiciderate  Suiciderate  Gunhomiciderate  \
# 0               Location  Gunsuiciderate  Suiciderate  Gunhomiciderate
# 1          United States             7.9         14.5              6.3
# 2                Wyoming            23.7         32.8              1.7
# 3                Montana            21.6         31.7              2.7
# 4                 Alaska            19.4         30.0              4.2
# 5             New Mexico            14.4         25.2             10.9
# 6               Oklahoma            13.8         22.0              6.4
# 7                  Idaho            13.8         20.4              1.5
# 8           North Dakota            13.2         20.1              2.6
# 9                 Nevada            13.1         22.0              6.3
# 10              Arkansas            12.9         20.4              9.3
# 11              Colorado            12.8         23.8              4.7
# ...

# %%
# por seguridad se copia la BD
df_clean = df.copy()
# Desde la linea 1 en adelante
df_clean = df_clean[1:]
df_clean
# Out:
#                 Location Gunsuiciderate Suiciderate Gunhomiciderate  \
# 1          United States            7.9        14.5             6.3
# 2                Wyoming           23.7        32.8             1.7
# 3                Montana           21.6        31.7             2.7
# 4                 Alaska           19.4        30.0             4.2
# 5             New Mexico           14.4        25.2            10.9
# 6               Oklahoma           13.8        22.0             6.4
# 7                  Idaho           13.8        20.4             1.5
# 8           North Dakota           13.2        20.1             2.6
# 9                 Nevada           13.1        22.0             6.3
# 10              Arkansas           12.9        20.4             9.3
# 11              Colorado           12.8        23.8             4.7
# 12         West Virginia           12.7        21.0             4.8
# 13               Alabama           12.4        16.4            12.9
# ...

# %%
df_clean.info()

# Los datos a excepcion de Location debe ser un número. Adicionalmente el %gun athome debe convertirse a % como número
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 1 to 52
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Location         52 non-null     object
#  1   Gunsuiciderate   52 non-null     object
#  2   Suiciderate      52 non-null     object
#  3   Gunhomiciderate  52 non-null     object
#  4   Homiciderate     52 non-null     object
#  5   %gun athome      52 non-null     object
# dtypes: object(6)
# memory usage: 2.6+ KB
